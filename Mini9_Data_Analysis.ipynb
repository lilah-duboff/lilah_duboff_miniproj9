# %% [markdown]
# <a href="https://colab.research.google.com/github/lilah-duboff/lilah_duboff_miniproj9/blob/main/Mini9_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Introduction

# %% [markdown]
# ##### In this project, we will be exploring and analyzing a free Kaggle dataset the contains information about the average hourly wages for different levels of education, over a span of approximately 50 years. The data is then further broken down by sex and race, allowing for demographics comparison of average pay by education level.

# %% [markdown]
# # Load Data

# %% [markdown]
# ##### We use pandas to load the url into a dataframe, and ensure that it succeeded by running an assert statement. Next, we check to see our column names, and if there are any null or missing numbers in the data.

# %%
data = pd.read_csv('https://raw.githubusercontent.com/lilah-duboff/data-for-URLS/refs/heads/main/wages_by_education.csv')

assert data is not None
assert data.shape == (50, 61)

# %%
data.head()
# Out:
#    year  less_than_hs  high_school  some_college  bachelors_degree  \
# 0  2022         16.52        21.94         24.81             41.60
# 1  2021         16.74        22.28         24.92             41.32
# 2  2020         17.02        22.70         25.44             41.65
# 3  2019         16.11        21.64         24.00             39.61
# 4  2018         15.94        21.50         23.70             38.87
#
#    advanced_degree  men_less_than_hs  men_high_school  men_some_college  \
# 0            53.22             17.99            24.08             27.96
# 1            53.45             18.34            24.36             27.96
# 2            53.74             18.76            25.09             28.55
# 3            51.57             17.55            23.99             26.99
# 4            51.03             17.70            23.72             26.61
#
#    men_bachelors_degree  ...  black_women_less_than_hs  \
# 0                 49.01  ...                     13.89
# 1                 47.83  ...                     13.73
# 2                 48.15  ...                     13.66
# 3                 45.74  ...                     13.30
# 4                 44.97  ...                     12.48
#
#    black_women_high_school  black_women_some_college  \
# 0                    17.83                     20.36
# 1                    18.30                     20.18
# 2                    17.93                     20.31
# 3                    17.18                     19.17
# 4                    16.81                     18.57
#
#    black_women_bachelors_degree  black_women_advanced_degree  \
# 0                         29.94                        39.41
# 1                         29.35                        40.07
# 2                         31.38                        42.44
# 3                         30.31                        40.42
# 4                         30.85                        39.64
#
#    hispanic_women_less_than_hs  hispanic_women_high_school  \
# 0                        14.74                       18.18
# 1                        14.97                       18.34
# 2                        14.58                       18.50
# 3                        14.50                       17.71
# 4                        13.47                       17.28
#
#    hispanic_women_some_college  hispanic_women_bachelors_degree  \
# 0                        20.64                            31.13
# 1                        21.14                            31.25
# 2                        20.69                            31.55
# 3                        19.69                            30.18
# 4                        19.29                            29.47
#
#    hispanic_women_advanced_degree
# 0                           40.64
# 1                           42.47
# 2                           44.15
# 3                           42.30
# 4                           39.35
#
# [5 rows x 61 columns]

# %% [markdown]
# ##### First five rows of the df

# %%
data.tail()
# Out:
#     year  less_than_hs  high_school  some_college  bachelors_degree  \
# 45  1977         17.59        21.50         22.97             31.07
# 46  1976         17.52        21.76         23.49             31.46
# 47  1975         17.30        21.55         23.30             31.45
# 48  1974         17.68        21.60         23.32             31.69
# 49  1973         18.06        22.22         24.08             32.80
#
#     advanced_degree  men_less_than_hs  men_high_school  men_some_college  \
# 45            37.36             20.43            25.97             26.70
# 46            37.50             20.36            26.14             27.10
# 47            38.41             20.00            26.02             26.93
# 48            38.37             20.63            26.15             26.79
# 49            38.16             21.18            26.90             27.67
#
#     men_bachelors_degree  ...  black_women_less_than_hs  \
# 45                 36.09  ...                     12.80
# 46                 36.42  ...                     12.75
# 47                 36.21  ...                     12.48
# 48                 36.62  ...                     12.31
# 49                 37.69  ...                     12.02
#
#     black_women_high_school  black_women_some_college  \
# 45                    16.30                     18.87
# 46                    16.40                     19.11
# 47                    15.88                     18.11
# 48                    15.55                     18.19
# 49                    15.79                     18.11
#
#     black_women_bachelors_degree  black_women_advanced_degree  \
# 45                         25.83                        37.10
# 46                         26.10                        34.92
# 47                         27.93                        33.03
# 48                         27.80                        33.86
# 49                         28.35                        41.81
#
#     hispanic_women_less_than_hs  hispanic_women_high_school  \
# 45                        12.66                       17.22
# 46                        13.79                       17.29
# 47                        12.87                       16.04
# 48                        13.24                       16.29
# 49                        12.92                       16.46
#
#     hispanic_women_some_college  hispanic_women_bachelors_degree  \
# 45                        17.12                            21.49
# 46                        17.40                            20.29
# 47                        17.04                            18.85
# 48                        18.17                            21.70
# 49                        20.22                            22.23
#
#     hispanic_women_advanced_degree
# 45                           30.31
# 46                           20.93
# 47                           23.63
# 48                           26.74
# 49                           25.10
#
# [5 rows x 61 columns]

# %% [markdown]
# ##### Last five rows of the df

# %%
print(data.columns)
# Out:
# Index(['year', 'less_than_hs', 'high_school', 'some_college',
#        'bachelors_degree', 'advanced_degree', 'men_less_than_hs',
#        'men_high_school', 'men_some_college', 'men_bachelors_degree',
#        'men_advanced_degree', 'women_less_than_hs', 'women_high_school',
#        'women_some_college', 'women_bachelors_degree', 'women_advanced_degree',
#        'white_less_than_hs', 'white_high_school', 'white_some_college',
#        'white_bachelors_degree', 'white_advanced_degree', 'black_less_than_hs',
#        'black_high_school', 'black_some_college', 'black_bachelors_degree',
#        'black_advanced_degree', 'hispanic_less_than_hs',
#        'hispanic_high_school', 'hispanic_some_college',
#        'hispanic_bachelors_degree', 'hispanic_advanced_degree',
#        'white_men_less_than_hs', 'white_men_high_school',
#        'white_men_some_college', 'white_men_bachelors_degree',
#        'white_men_advanced_degree', 'black_men_less_than_hs',
#        'black_men_high_school', 'black_men_some_college',
#        'black_men_bachelors_degree', 'black_men_advanced_degree',
#        'hispanic_men_less_than_hs', 'hispanic_men_high_school',
#        'hispanic_men_some_college', 'hispanic_men_bachelors_degree',
#        'hispanic_men_advanced_degree', 'white_women_less_than_hs',
#        'white_women_high_school', 'white_women_some_college',
#        'white_women_bachelors_degree', 'white_women_advanced_degree',
#        'black_women_less_than_hs', 'black_women_high_school',
#        'black_women_some_college', 'black_women_bachelors_degree',
#        'black_women_advanced_degree', 'hispanic_women_less_than_hs',
#        'hispanic_women_high_school', 'hispanic_women_some_college',
#        'hispanic_women_bachelors_degree', 'hispanic_women_advanced_degree'],
#       dtype='object')

# %%
data.isnull().values.any()
# Out:
# False

# %%
data.shape
# Out:
# (50, 61)

# %% [markdown]
# # Data Cleaning and Exploration

# %% [markdown]
# ##### We established that there are no missing values in this dataset, so we will move on to data exploration.

# %%
data.describe()
# Out:
#              year  less_than_hs  high_school  some_college  bachelors_degree  \
# count    50.00000     50.000000    50.000000     50.000000         50.000000
# mean   1997.50000     15.702600    20.876600     23.219200         34.768600
# std      14.57738      1.125252     0.742743      0.776425          3.306645
# min    1973.00000     13.950000    19.620000     22.040000         30.040000
# 25%    1985.25000     14.885000    20.392500     22.545000         31.875000
# 50%    1997.50000     15.340000    20.855000     23.185000         34.205000
# 75%    2009.75000     16.497500    21.480000     23.697500         37.122500
# max    2022.00000     18.060000    22.700000     25.440000         41.650000
#
#        advanced_degree  men_less_than_hs  men_high_school  men_some_college  \
# count        50.000000         50.000000        50.000000         50.000000
# mean         43.899000         17.565200        23.832600         26.333800
# std           5.305794          1.638445         1.225697          0.897943
# min          35.320000         15.390000        22.110000         24.780000
# 25%          38.757500         16.250000        22.945000         25.800000
# 50%          44.085000         16.905000        23.695000         26.365000
# 75%          47.557500         18.610000        24.307500         27.012500
# max          53.740000         21.180000        26.900000         28.550000
#
#        men_bachelors_degree  ...  black_women_less_than_hs  \
# count             50.000000  ...                  50.00000
# mean              39.988400  ...                  12.77180
# std                3.734945  ...                   0.46448
# min               35.160000  ...                  11.77000
# 25%               36.605000  ...                  12.45000
# 50%               39.485000  ...                  12.78000
# 75%               42.340000  ...                  13.02750
# max               49.010000  ...                  13.89000
#
#        black_women_high_school  black_women_some_college  \
# count                50.000000                 50.000000
# mean                 16.461400                 18.960400
# std                   0.700854                  0.733991
# min                  15.530000                 17.710000
# 25%                  15.862500                 18.412500
# 50%                  16.300000                 18.790000
# 75%                  16.992500                 19.580000
# max                  18.300000                 20.450000
#
#        black_women_bachelors_degree  black_women_advanced_degree  \
# count                     50.000000                    50.000000
# mean                      27.924400                    36.186200
# std                        2.417531                     3.123264
# min                       23.540000                    29.340000
# 25%                       25.985000                    33.870000
# 50%                       28.515000                    37.160000
# 75%                       30.110000                    38.312500
# max                       31.380000                    42.440000
#
#        hispanic_women_less_than_hs  hispanic_women_high_school  \
# count                    50.000000                   50.000000
# mean                     12.808200                   16.597600
# std                       0.752798                    0.685984
# min                      11.350000                   15.530000
# 25%                      12.275000                   16.115000
# 50%                      12.725000                   16.465000
# 75%                      13.075000                   16.982500
# max                      14.970000                   18.500000
#
#        hispanic_women_some_college  hispanic_women_bachelors_degree  \
# count                    50.000000                        50.000000
# mean                     18.963600                        26.487400
# std                       0.954833                         3.219796
# min                      17.040000                        18.850000
# 25%                      18.292500                        24.237500
# 50%                      18.930000                        27.390000
# 75%                      19.645000                        28.702500
# max                      21.140000                        31.550000
#
#        hispanic_women_advanced_degree
# count                        50.00000
# mean                         34.75360
# std                           5.20913
# min                          20.93000
# 25%                          30.95500
# 50%                          36.08500
# 75%                          38.37000
# max                          44.15000
#
# [8 rows x 61 columns]

# %%
less_than_hs = np.mean(data["less_than_hs"])
hs = np.mean(data["high_school"])
some_college = np.mean(data["some_college"])
bachelors = np.mean(data["bachelors_degree"])
advanced_degree = np.mean(data["advanced_degree"])

men_with_bach = np.mean(data["men_bachelors_degree"])
women_with_bach = np.mean(data["women_bachelors_degree"])

men_with_adv = np.mean(data["men_advanced_degree"])
women_with_adv = np.mean(data["women_advanced_degree"])

# %% [markdown]
# # Data Analysis

# %%
men_data = {
    'Year': data["year"],
    'Advanced degree': data["men_advanced_degree"],
    'Bachelors degree': data["men_bachelors_degree"],
    'Some college': data["men_some_college"],
    'High school': data["men_high_school"],
    'Less than high school': data["men_less_than_hs"]
}

df = pd.DataFrame(men_data)

df_long = pd.melt(df, id_vars=['Year'],
                  value_vars=['Advanced degree', 'Bachelors degree', 'Some college', 'High school', 'Less than high school'],
                  var_name='Education_Level', value_name='Wages')

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

sns.lineplot(data=df_long, x='Year', y='Wages', hue='Education_Level', legend="full")
plt.title("Average Hourly Wages by Education Level (Men)")
plt.xlabel("Year")
plt.ylabel("Average Hourly Wages")
plt.legend(title='Education Level')

plt.show()

# %%
women_data = {
    'Year': data["year"],
    'Advanced degree': data["women_advanced_degree"],
    'Bachelors degree': data["women_bachelors_degree"],
    'Some college': data["women_some_college"],
    'High school': data["women_high_school"],
    'Less than high school': data["women_less_than_hs"]
}

df = pd.DataFrame(women_data)

df_long = pd.melt(df, id_vars=['Year'],
                  value_vars=['Advanced degree', 'Bachelors degree', 'Some college', 'High school', 'Less than high school'],
                  var_name='Education_Level', value_name='Wages')

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

sns.lineplot(data=df_long, x='Year', y='Wages', hue='Education_Level', legend="full")
plt.title("Average Hourly Wages by Education Level (Women)")
plt.xlabel("Year")
plt.ylabel("Average Hourly Wages")
plt.legend(title='Education Level')

plt.show()

# %%
education_levels = ['Less than HS', 'High School', 'Some College', 'Bachelors', 'Advanced Degree']
average_wages = data.iloc[0, 1:6]

plt.figure(figsize=(8, 6))
plt.bar(education_levels, average_wages)
plt.title("Average Hourly Wages by Education Level in 2022")
plt.xlabel("Education Level")
plt.ylabel("Average Hourly Wage")
plt.show()

# %%
education_levels = ['Less than HS', 'High School', 'Some College', 'Bachelors', 'Advanced Degree']
average_wages = data.iloc[49, 1:6]

plt.figure(figsize=(8, 6))
plt.bar(education_levels, average_wages)
plt.title("Average Hourly Wages by Education Level in 1973")
plt.xlabel("Education Level")
plt.ylabel("Average Hourly Wage")
plt.show()

# %%
# 2. Bar graph comparing men vs. women with a bachelor's degree
plt.figure(figsize=(6, 6))
plt.bar(['Men with Bachelors', 'Women with Bachelors'], [men_with_bach, women_with_bach], color=['blue', 'pink'])
plt.title("Average Hourly Wages: Men vs Women with Bachelor's Degree")
plt.xlabel("Group")
plt.ylabel("Average Hourly Wage (2001 Dollars)")
plt.show()

# %%
# 3. Bar graph comparing men vs. women with an advanced degree
plt.figure(figsize=(6, 6))
plt.bar(['Men with Advanced Degree', 'Women with Advanced Degree'], [men_with_adv, women_with_adv], color=['blue', 'pink'])
plt.title("Average Hourly Wages: Men vs Women with Advanced Degree")
plt.xlabel("Group")
plt.ylabel("Average Hourly Wage (2001 Dollars)")
plt.show()

# %% [markdown]
# # Conclusions and Recommendations
